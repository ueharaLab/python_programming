# %% [markdown]
# # ドジャーズの勝ちパターン（負けパターン）を見つけ出す
# - 何回に得点すると勝つ傾向が高いか
# - 大谷がホームランを打つと勝ちやすいか
# - MVBトリオと勝ちパターン
# - その他、配列をつくってパターンを見つけ出す工夫をしてみる

# %% [markdown]
# # MLBデータ
# ## 大谷翔平の2024成績
# - 以下のリンクから大谷翔平の2024年の試合別の成績一覧を表示できる(下表）
# - https://www.statmuse.com/mlb/player/shohei-ohtani-67561/game-log?seasonYear=2024&perspective=batting&statType=standard
# - 記号の意味　OPP:対戦相手　SCORE: W（勝）L(負）AB: 打席数　H:シングルヒット 2B:２塁打　3B:３塁打 HR:ホームラン
# - 日付部分をクリックするとスコアボードが表示される
#
# <img src="attachment:f8bbf8e6-9b9e-4188-9088-58e40f13008f.png" width="50%">

# %% [markdown]
# ## ドジャースの2024成績
# 以下のリンクからドジャースの2024年の試合別の成績一覧を表示できる(下表）
# https://www.statmuse.com/mlb/team/los-angeles-dodgers-31/schedule/2024
# <img src="attachment:ded20b62-7237-4e37-a50f-265c4959241e.png" width="30%">

# %% [markdown]
# ## スコアボード
# 上表いずれかの日付をクリックすると以下のような試合のスコアボードが表示される
# https://www.statmuse.com/mlb/game/9-3-2024-lad-at-laa-231568
#
# - 得点シーンの例 Top 3：3回表，
# Shohei Ohtani triples to right field. Miguel Rojas scores：大谷翔平が3塁打(Triple)を打ち、ロハスがホームを踏んだ(scores).e
#
#
#
# <img src="attachment:484dc173-b8f9-4ea6-a051-fff8b899cc42.png" width="50%"
#
# >

# %% [markdown]
# ## 得点シーンでの打撃
# 得点シーンをクリックすると、タイムリーを打つまでの配球が表示される　⇒　各選手がどのような球種、球速に強いかがわかる
# <img src="attachment:334387d2-46cd-45f9-98cf-a6903341d849.png" width="20%">

# %% [markdown]
# # MLBデータ
# ### 1. ドジャース2024 ゲーム毎の勝敗と成績
# https://www.baseball-reference.com/teams/LAD/2024-schedule-scores.shtml#all_team_schedule
# ### 2. ドジャース2024 ゲーム毎の打撃成績詳細
# 日付をクリックするとスコアボードおよび選手別の各回のパフォーマンスが表示される
# https://www.foxsports.com/mlb/los-angeles-dodgers-team-game-log?category=hitting&season=2024&seasonType=reg
# ### 3. 大谷翔平2024 ゲーム毎の打撃成績
# 日付をクリックするとスコアボードと各回の得点詳細も表示される
# https://www.statmuse.com/mlb/player/shohei-ohtani-67561/game-log?seasonYear=2024&perspective=batting&statType=standard
# - 得点シーンの例 Top 3：3回表，
# Shohei Ohtani triples to right field. Miguel Rojas scores：大谷翔平が3塁打(Triple)を打ち、ロハスがホームを踏んだ(scores).e
# <img src="attachment:484dc173-b8f9-4ea6-a051-fff8b899cc42.png" width="50%">
# ### 4. 大谷翔平2024 ゲーム毎　打席毎のパフォーマンス
# https://times.abema.tv/articles/-/10018233

# %% [markdown]
# その他参考リンク
# https://www.mlb.com/player/shohei-ohtani-660271?stats=gamelogs-r-hitting-mlb&year=2024
# https://www.espn.com/mlb/team/schedule/_/name/lad/seasontype/2/half/2
# https://www.baseball-reference.com/teams/LAD/2024-schedule-scores.shtml#all_team_schedule
# https://fixturedownload.com/results/mlb-2024/los-angeles-dodgers
# https://www.espn.com/mlb/game/_/gameId/401569928/red-sox-dodgers
# https://www.foxsports.com/mlb/los-angeles-dodgers-team-game-log?category=hitting&season=2024&seasonType=reg
# https://www.foxsports.com/mlb/los-angeles-dodgers-vs-colorado-rockies-sep-29-2024-game-boxscore-90645?tab=boxscore

# %%
以下はMLBのある日の試合スコアである。これをもとにして以下の問いに従って配列を作成せよ  
<img src="attachment:82fb16b1-6ea8-457f-9822-8df7715cd0a7.png" width="60%">

# %%
1. １回から９回までの両チームのスコア表を以下のように作成せよ。データ型はnumpyとする
2. 各チームの得点を計算して、1.の表の最後の列に追加せよ

# %%
分析に役立ちそうなプログラミング
グループ分けする

# %%
合計　平均など

# %%
条件にあてはまるデータだけを抽出

# %%
特定の列と行を取り出す
参考：第３回
